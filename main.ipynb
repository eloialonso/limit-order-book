# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

from src import display_order_menu, maslov, LOB

# %% [markdown]
# # Limit order book

# %%
lob = LOB()

t = 0
while True:
    order = display_order_menu()
    if order is None:
        break
    
    order.time = t
    lob.place(order)
        
    lob.render(show_price=False)
    t += 1

# %% [markdown]
# # Maslov model

# %%
params = {
    'price0': 100,
    'T': 5000,
    'p_limit': 0.5,
    'p_sell': 0.5,
    'max_quantity': 1,
    'max_delta_price': 1,
}

# %%
# Simulate a number steps
lob = maslov(**params)
lob.render()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# interactive
_ = maslov(interactive=True, **params)
